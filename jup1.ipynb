# %%
# %run newmain.py
# Out:
# /home/ilia/Desktop/work/res_daset
# asasasas = /home/ilia/Desktop/work/res_daset
# Current working directory:11 /home/ilia/Desktop/work/res_daset
# Elapsed time 1: 0.00 seconds
# Elapsed time 2: 0.00 seconds
# Elapsed time 3: 0.00 seconds
# Processing element: habitat
# ...

# %%
test1 = True
test2= False
if not test1 or not test2:
    print("hallucination")
else:    
    print('aa')
# Out:
# hallucination
